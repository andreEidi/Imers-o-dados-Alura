# %% [markdown]
# <a href="https://colab.research.google.com/github/andreEidi/Imersao-dados-Alura/blob/main/ImersaoDados1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMERSÃO DADOS - ALURA 2021

# %% [markdown]
# ---
#
# # Aula 1: Análise de dados, python, pandas e novos fármacos
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

url_dados='https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0']>0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0']>0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ---
# ## Desafios Aula 1:
#
#
# ---

# %% [markdown]
# ###Desafio 01: investigar pq a classe tratamento é tão desbalanceada??

# %% [markdown]
# > Sabe-se que, em geral, o grupo controle é aquele para o qual não seria aplicado nenhum tipo de droga. Esse grupo é um parâmetro para o qual é possível realizar comparações a fim de validar resultados experimentais.
#
#
#
#
# > Note que ao exibir somente os experimentos controle e a identificação da droga usada, obtemos sempre o mesmo identificador. Isso deve indicar que esse valor (cacb2b860) corresponde a não adição de nenhum tipo de químico. Sendo assim, não foi necessário produzir realizar tantos experimentos controle, visto que todos são comparados em relação a mesma condição

# %%
#Seleciona somente os aqueles experimentos com o parâmetro tratamento setados como com_controle
#Em seguida, exibir somente as colunas tratamento e droga
d = dados[dados['tratamento']=='com_controle']
d[['tratamento', 'droga']]
# Out:
#          tratamento      droga
# 25     com_controle  cacb2b860
# 38     com_controle  cacb2b860
# 40     com_controle  cacb2b860
# 47     com_controle  cacb2b860
# 63     com_controle  cacb2b860
# ...             ...        ...
# 23729  com_controle  cacb2b860
# 23747  com_controle  cacb2b860
# 23768  com_controle  cacb2b860
# 23793  com_controle  cacb2b860
# 23811  com_controle  cacb2b860
#
# [1866 rows x 2 columns]

# %% [markdown]
# ###Desafio 02: Plotar as 5 ultimas linhas da tabela

# %% [markdown]
# > Para exibir somente as últimas cinco linhas do dataFrame usa-se o comando tail()

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03:Proporção das classes tratamento

# %% [markdown]
# > Pode-se calcular a proporção por meio do método de normalização da função value_counts
#
#
#
# > Sendo assim, o tratamento com droga representa, aproximadamente, 92% do total de dados enquanto a amostra com_controle representa cerca de 8% do total dos dados

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ###Desafio 04: Quantas tipos de drogas foram investigados?

# %% [markdown]
# > Observa-se que a função value_counts() exibi ao final da linha de impressão quantas drogas foram usadas, no caso 3289 drogas diferentes (Contando com o experimento controle)

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# a1a9a44dd       1
# 209a68d23       1
# f49a73cd5       1
# f5c443039       1
# 153840764       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# ###Desafio 05: Procurar na documentação o metodo query(Pandas)

# %% [markdown]
# > O método query pode ser usado para filtrar uma certa quantidade de dados por meio de parâmetros fornecidos pelo programador
#
#
#
# > https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
dados.query("tratamento == 'com_controle'")
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# ###Desafio 06: Legendar e nomear os gráficos (mathplotlib.pyplot)

# %%
dados['tempo'].value_counts().sort_index().plot.bar(figsize = (8,8), color = ['red', 'purple', 'blue'])
plt.title('Frequência x Tempo')
plt.xlabel('Tempo')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# ### Desafio 07: Renomear as colunas tirando o hifen(-)

# %%
dados.columns = dados.columns.str.replace("-", "")
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# > Nesse primeiro momento buscou-se introduzir a plataforma na qual as aulas serão ministradas, discutir algumas bibliotecas do python que serão usadas, tais como o Pandas e o Mathplotlib e, por fim, analisar os primeiros dados referentes a ação de uma determinada droga em um gene.
#
# > O projeto proposto para a realização durante o curso foi de analisar dados referentes a ação de diferentes drogas em culturas de células humanas a fim de identificar qual proteína alvo está relacionada a uma determinada doença e assim desenvolver uma molécula que possa modular essa proteína alvo
#
# > Assim, observamos como importar as bibliotecas Pandas e Matplotlib e como ler arquivos em csv. Além disso, aprendemos como usar algumas funções próprias dessas bibliotecas afim de podermos lidar com um conjunto de dados, tais como:
#
#
# > unique: mostrar valores,sem repetições, dos valores que o parâmetro pode receber
#
# > value_counts: conta quanta vezes um valor aparece
#
# > value_counts(normalize = true): normaliza os dados obtidos pela função acima
#
# > query: seleciona uma fatia dos dados com base em parâmetros
#
# > head: mostra as cinco primeiras linhas dos dados
#
# > tail: mostra as últimas cinco linhas do conjunto de dados
#
# > plot.bar: Plota um gráfico de barras dos dados coletados
#
# > plot.pie: Plota um gráfico de pizza dos dados
