# %% [markdown]
# <a href="https://colab.research.google.com/github/andreEidi/Imersao-dados-Alura/blob/main/ImersaoDadosAula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMERSÃO DADOS - ALURA 2021

# %% [markdown]
# ---
#
# # Aula 4: Merge de dados e análise de resultados
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url_dados_resultados='https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true'
url_dados='https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados_resultados = pd.read_csv(url_dados_resultados)
dados = pd.read_csv(url_dados, compression = 'zip')
dados_resultados.head()
#Mecanismos de ação -> alvo e ação que tem sobre o alvo
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
#troca o nome da coluna droga para composto
#inplace troca permanentemente
mapa = {'droga': 'composto'}
dados.rename(columns = mapa, inplace = True)

# %%
#mostra os valores unicos que estão relacionados com o acat_inhibitor	
#0 indica q um determinado mecanismo de ação não é ativado
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
#Qual foi o mecanismo de ação mais ativado?
#Seleciona somente as colunas númericas
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#Indica para ignorar a coluna id
#\Ideia slipt(_)
contagem_moa = dados_resultados.drop('id', axis = 1).sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#Assim nossa primeira linha ativou um mecanismo de ação, a segunda não ativou...
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Queremos relacionar em uma única tabela os resultados e os dados iniciais
#Primeiro criamos uma coluna em dados_resultados com o numero de vezes que um composto ativou um mecanismo de ação
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dados_resultados['n_moa']!=0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
#Criar uma nova coluna que indica se aquele composto ativou algum mecanismo de ação
dados_resultados['ativo_moa'] = (dados_resultados['n_moa']!=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'ativo_moa')

# %% [markdown]
# ## Desafios aula 4

# %% [markdown]
# ### Desafio 1: Encontrar o top 10 das ações do MOA (inibidor, agonista...)

# %%
###Tive mais dificuldade nesse desafio, então recorri a ajuda de outras pessoas no discord da imersão

#reset_index adiciona uma coluna no começa para que sejam mostrados de forma enumerada ao invés do index anterior
cont_moa = dados_resultados.drop(['id', 'n_moa', 'ativo_moa'], axis = 1).sum().sort_values(ascending = False).reset_index()
cont_moa.columns = ['Moa', 'contagem']
cont_moa
# Out:
#                                             Moa  contagem
# 0                                nfkb_inhibitor       832
# 1                          proteasome_inhibitor       726
# 2                      cyclooxygenase_inhibitor       435
# 3                  dopamine_receptor_antagonist       424
# 4                 serotonin_receptor_antagonist       404
# ..                                          ...       ...
# 201               protein_phosphatase_inhibitor         6
# 202                         autotaxin_inhibitor         6
# 203                                    diuretic         6
# 204                             erbb2_inhibitor         1
# 205  atp-sensitive_potassium_channel_antagonist         1
#
# [206 rows x 2 columns]

# %%
acao = cont_moa['Moa'].str.split('_')
lista_acao=[]
for i in acao:
  lista_acao.append(i[-1])
lista_acao
# Out:
# ['inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'blocker',
#  'inhibitor',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'antagonist',
#  'agonist',
#  'inhibitor',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'antagonist',
#  'agonist',
#  'inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'agonist',
#  'agonist',
#  'agonist',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'local',
#  'inhibitor',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'anti-inflammatory',
#  'inhibitor',
#  'antioxidant',
#  'immunosuppressant',
#  'inhibitor',
# ...

# %%
cont_moa['Ação'] = lista_acao
cont_moa
# Out:
#                                             Moa  contagem        Ação
# 0                                nfkb_inhibitor       832   inhibitor
# 1                          proteasome_inhibitor       726   inhibitor
# 2                      cyclooxygenase_inhibitor       435   inhibitor
# 3                  dopamine_receptor_antagonist       424  antagonist
# 4                 serotonin_receptor_antagonist       404  antagonist
# ..                                          ...       ...         ...
# 201               protein_phosphatase_inhibitor         6   inhibitor
# 202                         autotaxin_inhibitor         6   inhibitor
# 203                                    diuretic         6    diuretic
# 204                             erbb2_inhibitor         1   inhibitor
# 205  atp-sensitive_potassium_channel_antagonist         1  antagonist
#
# [206 rows x 3 columns]

# %%
top10 = cont_moa.groupby('Ação').agg({'contagem': 'sum'}).sort_values('contagem', ascending=False)
top10.head(10)
# Out:
#                    contagem
# Ação
# inhibitor              9693
# antagonist             3449
# agonist                2330
# blocker                 323
# agent                   150
# activator               115
# local                    80
# antioxidant              73
# anti-inflammatory        73
# immunosuppressant        73

# %% [markdown]
# ### Desafio2: Criar a coluna eh_controle para quando na linha tratamento == com_controle com valores booleanos

# %% [markdown]
# > Bloco com recuo

# %%
dados_combinados['eh_controle'] = dados_combinados['tratamento'] == 'com_controle'
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# ### Desafio 3: Criar três colunas com 24, 48 e 72 horas

# %%
dados_combinados['eh_24h'] = dados_combinados['tempo'] == 24
dados_combinados
# Out:
#                  id    tratamento  tempo  ... ativo_moa eh_controle  eh_24h
# 0      id_000644bb2     com_droga     24  ...      True       False    True
# 1      id_000779bfc     com_droga     72  ...     False       False   False
# 2      id_000a6266a     com_droga     48  ...      True       False   False
# 3      id_0015fd391     com_droga     48  ...     False       False   False
# 4      id_001626bd3     com_droga     72  ...      True       False   False
# ...             ...           ...    ...  ...       ...         ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...      True       False    True
# 23810  id_fffb70c0c     com_droga     24  ...      True       False    True
# 23811  id_fffc1c3f4  com_controle     48  ...     False        True   False
# 23812  id_fffcb9e7c     com_droga     24  ...      True       False    True
# 23813  id_ffffdd77b     com_droga     72  ...     False       False   False
#
# [23814 rows x 881 columns]

# %%
dados_combinados['eh_48h'] = dados_combinados['tempo'] == 48
dados_combinados
# Out:
#                  id    tratamento  tempo  ... eh_controle eh_24h  eh_48h
# 0      id_000644bb2     com_droga     24  ...       False   True   False
# 1      id_000779bfc     com_droga     72  ...       False  False   False
# 2      id_000a6266a     com_droga     48  ...       False  False    True
# 3      id_0015fd391     com_droga     48  ...       False  False    True
# 4      id_001626bd3     com_droga     72  ...       False  False   False
# ...             ...           ...    ...  ...         ...    ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...       False   True   False
# 23810  id_fffb70c0c     com_droga     24  ...       False   True   False
# 23811  id_fffc1c3f4  com_controle     48  ...        True  False    True
# 23812  id_fffcb9e7c     com_droga     24  ...       False   True   False
# 23813  id_ffffdd77b     com_droga     72  ...       False  False   False
#
# [23814 rows x 882 columns]

# %%
dados_combinados['eh_72h'] = dados_combinados['tempo'] == 72
dados_combinados
# Out:
#                  id    tratamento  tempo  ... eh_24h eh_48h  eh_72h
# 0      id_000644bb2     com_droga     24  ...   True  False   False
# 1      id_000779bfc     com_droga     72  ...  False  False    True
# 2      id_000a6266a     com_droga     48  ...  False   True   False
# 3      id_0015fd391     com_droga     48  ...  False   True   False
# 4      id_001626bd3     com_droga     72  ...  False  False    True
# ...             ...           ...    ...  ...    ...    ...     ...
# 23809  id_fffb1ceed     com_droga     24  ...   True  False   False
# 23810  id_fffb70c0c     com_droga     24  ...   True  False   False
# 23811  id_fffc1c3f4  com_controle     48  ...  False   True   False
# 23812  id_fffcb9e7c     com_droga     24  ...   True  False   False
# 23813  id_ffffdd77b     com_droga     72  ...  False  False    True
#
# [23814 rows x 883 columns]

# %% [markdown]
# ### Desafio 4: Estudar combinações de dataframes

# %% [markdown]
# ### Desafio 5: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga para comparar com o controle)

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'tratamento')

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'dose')

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g-0', x = 'composto', hue = 'tempo')

# %% [markdown]
# ### Desfio 6: Descobrir se temos algum composto que dependendo da configuração do experimento ativa ou não ativa um MOA

# %%
dados_combinados.head(50)
# Out:
#               id    tratamento  tempo dose  ... eh_controle  eh_24h  eh_48h  eh_72h
# 0   id_000644bb2     com_droga     24   D1  ...       False    True   False   False
# 1   id_000779bfc     com_droga     72   D1  ...       False   False   False    True
# 2   id_000a6266a     com_droga     48   D1  ...       False   False    True   False
# 3   id_0015fd391     com_droga     48   D1  ...       False   False    True   False
# 4   id_001626bd3     com_droga     72   D2  ...       False   False   False    True
# 5   id_001762a82     com_droga     24   D1  ...       False    True   False   False
# 6   id_001bd861f     com_droga     24   D2  ...       False    True   False   False
# 7   id_0020d0484     com_droga     48   D1  ...       False   False    True   False
# 8   id_00224bf20     com_droga     48   D1  ...       False   False    True   False
# 9   id_0023f063e     com_droga     48   D2  ...       False   False    True   False
# ...

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g-45', x = 'composto', hue = 'tempo')

# %% [markdown]
# > Pela tabela e pelo gráfico de boxplot notamos que o gene 45 quando aplicado ao composto 87d714366 age de maneira dependente da configuração. Isto é, em um tempo de 24h a ação desse composto no gene é baixo, próximo a ação do composto controle cacb2b860, mas quando aplicado em tempos maiores ele começa a ter efeitos mais perceptíveis e fora do padrão do controle

# %% [markdown]
# ### Desafio 7: ativa Moa's diferentes dependendo da configuração

# %% [markdown]
# > Como visto no item anterior diferentes configurações podem ativar Moa's diferentes

# %% [markdown]
# ### Desafio 8: Resumo da aula

# %% [markdown]
# > Nesse aula aprendemos diversas novas funções tais como merge, que possibilita juntar dois dataframes diferentes. Além disso, pudemos trabalhar com um novo conjunto de dados, um de resultados a fim de analisá-los e obter mais informações sobre como um composto age em um célula
